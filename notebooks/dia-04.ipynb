# %% [markdown]
# https://pypi.org/project/chempy/

# %%
# !pip install chempy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 402 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 242 kB 42.9 MB/s
# ...
#      |████████████████████████████████| 14.2 MB 34.9 MB/s
# ...
#      |████████████████████████████████| 120 kB 26.3 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 34.2 MB/s
# ...
#      |████████████████████████████████| 82 kB 409 kB/s
# ...
#   Created wheel for chempy: filename=chempy-0.8.0-py2.py3-none-any.whl size=207591 sha256=8c9bfe8087ed5d26285253f62e8d20dcbbf6076ffc2c357e065f9378ee1d605c
#   Stored in directory: /root/.cache/pip/wheels/3b/5e/75/4b4e5aaa7d88de5fc6daaabc927641482b4df51570836ceb64
# ...
#   Created wheel for pyneqsys: filename=pyneqsys-0.5.7-py2.py3-none-any.whl size=27285 sha256=589b0d6bec792fb86ca86a1eb2db129532f5f3727bb9363b142fba489a2551dc
# ...
